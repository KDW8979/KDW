# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import time
from openpyxl import Workbook

# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 엑셀 워크북 설정
wb = Workbook(write_only=True)
ws = wb.create_sheet()

# ChromeDriver 경로 설정
service = Service(executable_path=r"C:\Users\kdp\Desktop\KDW\EX_자연어처리\D1010\chromedriver-win64\chromedriver.exe")
driver = webdriver.Chrome(service=service)
driver.get("https://www.youtube.com/watch?v=9EsKLveY3Rc&list=PLOBbhydezQbcZ_XJahmfTgQi9GIRDeM2o&index=125")
driver.implicitly_wait(3)
time.sleep(1.5)

# 초기 스크롤 다운
driver.execute_script("window.scrollTo(0, 800)")
time.sleep(3)

# %%
# 페이지 끝까지 스크롤 다운 반복
last_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(2)
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(1.5)

# %%
# # '더보기' 버튼 클릭 (추가 댓글 로드)
# while True:
#     try:
#         more_buttons = driver.find_elements(By.CSS_SELECTOR, "#more-replies > a")
#         for button in more_buttons:
#             driver.execute_script("arguments[0].click();", button)
#             time.sleep(1.5)
#     except:
#         break

# %%
# 페이지 소스 가져오기
html_source = driver.page_source
soup = BeautifulSoup(html_source, 'html.parser')

# 댓글 요소 찾기
comment_list = soup.select("yt-formatted-string#content-text")

# 댓글 텍스트 추출
comment_final = []
for i in range(len(comment_list)):

    temp_comment = comment_list[i].text
    temp_comment = temp_comment.replace('\n', '')
    temp_comment = temp_comment.replace('\t', '')
    temp_comment = temp_comment.replace('    ', '')
    comment_final.append(temp_comment) # 댓글 내용

# %%
# 데이터프레임 생성
pd_data = {"댓글 내용": comment_final}
youtube_pd = pd.DataFrame(pd_data)

# 엑셀 파일로 저장
youtube_pd.to_excel(r"C:\Users\kdp\Desktop\KDW\EX_자연어처리\data\무한도전\무인도 특집.xlsx", index=False)

# 드라이버 닫기
driver.quit()

# %%
# 초기 스크롤 다운
driver.execute_script("window.scrollTo(0, 800)")
time.sleep(3)

# 페이지 끝까지 스크롤 다운 반복
last_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(2)
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(1.5)



# 페이지 소스 가져오기
html_source = driver.page_source
soup = BeautifulSoup(html_source, 'html.parser')

# 댓글 요소 찾기
comment_list = soup.select("yt-formatted-string#content-text")

# 댓글 텍스트 추출
comment_final = []
for i in range(len(comment_list)):

    temp_comment = comment_list[i].text
    temp_comment = temp_comment.replace('\n', '')
    temp_comment = temp_comment.replace('\t', '')
    temp_comment = temp_comment.replace('    ', '')
    comment_final.append(temp_comment) # 댓글 내용

# 데이터프레임 생성
pd_data = {"댓글 내용": comment_final}
youtube_pd = pd.DataFrame(pd_data)

# 엑셀 파일로 저장
youtube_pd.to_excel(r"C:\Users\kdp\Desktop\KDW\EX_자연어처리\data\무한도전\무인도 특집.xlsx", index=False)

# 드라이버 닫기
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File c:\Users\kdp\anaconda3\envs\TORCH_TEXT\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # 초기 스크롤 다운
# ----> 2 driver.execute_script("window.scrollTo(0, 800)")
#       3 time.sleep(3)
#       5 # 페이지 끝까지 스크롤 다운 반복
#
# File c:\Users\kdp\anaconda3\envs\TORCH_TEXT\lib\site-packages\selenium\webdriver\remote\webdriver.py:414, in WebDriver.execute_script(self, script, *args)
# ...

# %%
# 경고 무시
import warnings
warnings.filterwarnings('ignore')

# 엑셀 워크북 설정
wb = Workbook(write_only=True)
ws = wb.create_sheet()

# ChromeDriver 경로 설정
service = Service(executable_path=r"C:\Users\kdp\Desktop\KDW\EX_자연어처리\D1010\chromedriver-win64\chromedriver.exe")
driver = webdriver.Chrome(service=service)
driver.get("https://www.youtube.com/watch?v=9EsKLveY3Rc&list=PLOBbhydezQbcZ_XJahmfTgQi9GIRDeM2o&index=125")
driver.implicitly_wait(3)
time.sleep(1.5)

# 초기 스크롤 다운
driver.execute_script("window.scrollTo(0, 800)")
time.sleep(3)

# 페이지 끝까지 스크롤 다운 반복
last_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    time.sleep(2)
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

time.sleep(1.5)

# '더보기' 버튼 클릭 (추가 댓글 로드)
while True:
    try:
        more_buttons = driver.find_elements(By.CSS_SELECTOR, "#more-replies > a")
        for button in more_buttons:
            driver.execute_script("arguments[0].click();", button)
            time.sleep(1.5)
    except:
        break

# 페이지 소스 가져오기
html_source = driver.page_source
soup = BeautifulSoup(html_source, 'html.parser')

# 댓글 요소 찾기
comment_list = soup.select("yt-formatted-string#content-text")

# 댓글 텍스트 추출
comment_final = []
for i in range(len(comment_list)):

    temp_comment = comment_list[i].text
    temp_comment = temp_comment.replace('\n', '')
    temp_comment = temp_comment.replace('\t', '')
    temp_comment = temp_comment.replace('    ', '')
    comment_final.append(temp_comment) # 댓글 내용

# 데이터프레임 생성
pd_data = {"댓글 내용": comment_final}
youtube_pd = pd.DataFrame(pd_data)

# 엑셀 파일로 저장
youtube_pd.to_excel(r"C:\Users\kdp\Desktop\KDW\EX_자연어처리\data\무한도전\무인도 특집.xlsx", index=False)

# 드라이버 닫기
driver.quit()
